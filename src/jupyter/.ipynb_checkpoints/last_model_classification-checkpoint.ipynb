# %%
#%matplotlib notebook
import pandas as pd
import numpy as np
from sklearn.externals import joblib
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.preprocessing import Imputer
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn import svm
from collections import Counter
import seaborn as sns
import itertools
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# %%
dataset = pd.read_csv('../../data/full_dataset/full_data_new_features.csv')
dataset = dataset.drop(dataset.columns[0], axis = 1)
dataset_set = set(dataset)
dataset.head()
# Out:
#    TLE4_PCA  TLE4_LDA  TLE4_mean  TLE4_variance  IGF2BP2_PCA  IGF2BP2_LDA  \
# 0 -0.073001 -0.253146        0.0            0.0    -0.229009    -0.181177
# 1 -0.073001 -0.253146        0.0            0.0    -0.229009    -0.181177
# 2 -0.073001 -0.253146        0.0            0.0    -0.229009    -0.181177
# 3 -0.073001 -0.253146        0.0            0.0    -0.229009    -0.181177
# 4 -0.073001 -0.253146        0.0            0.0    -0.229009    -0.181177
#
#    IGF2BP2_mean  IGF2BP2_variance  NOTCH2_PCA  NOTCH2_LDA   ...    \
# 0           0.0               0.0    0.315317   -0.009725   ...
# 1           0.0               0.0    0.634513    0.409493   ...
# 2           0.0               0.0   -0.949195    1.280339   ...
# 3           0.0               0.0    1.081059   -1.659938   ...
# 4           0.0               0.0    0.315317   -0.009725   ...
#
#    CHIC1_variance  ATRX_PCA  ATRX_LDA  ATRX_mean  ATRX_variance   CHM_PCA  \
# 0             0.0 -0.640449  0.923010        2.0            0.0 -0.371366
# 1             0.0  1.359551 -1.959372        0.0            0.0 -0.371366
# 2             0.0  1.359551 -1.959372        0.0            0.0 -0.371366
# 3             0.0  1.359551 -1.959372        0.0            0.0  0.429555
# 4             0.0 -0.640449  0.923010        2.0            0.0 -0.371366
#
#    CHM_LDA  CHM_mean  CHM_variance  labels
# 0 -0.19022  0.000000      0.000000       1
# 1 -0.19022  0.000000      0.000000       1
# 2 -0.19022  0.000000      0.000000       1
# 3  3.94475  0.666667      0.888889       1
# 4 -0.19022  0.000000      0.000000       1
#
# [5 rows x 561 columns]

# %%
# Start by only using known risk genes
# at: data/knownvariants/risk_genes.csv

knownvariants = pd.read_csv('../../data/knownvariants/risk_genes.csv', sep = ';')
locus_set = set(knownvariants['Locus'])
knownvariants.head()
# Out:
#          Locus Chr  Risk allele frequency        OR (95%CI)
# 0       NOTCH2   1                   0.11  1.13 (1.08-1.17)
# 1        PROX1   1                   0.50  1.07 (1.05-1.09)
# 2         IRS1   2                   0.61  1.19 (1.13-1.25)
# 3        THADA   2                   0.92  1.15 (1.10-1.20)
# 4  RBMS1/ITGB6   2                   0.57  1.11 (1.08-1.16)

# %%
# making list of features
risk_features = []
for feature in list(dataset):
    for locus in knownvariants['Locus']:
        if locus in feature:
            risk_features.append(feature)

dataset_risk_genes = dataset[risk_features]
dataset_risk_genes.head()
# Out:
#    TLE4_PCA  TLE4_LDA  TLE4_mean  TLE4_variance  IGF2BP2_PCA  IGF2BP2_LDA  \
# 0 -0.073001 -0.253146        0.0            0.0    -0.229009    -0.181177
# 1 -0.073001 -0.253146        0.0            0.0    -0.229009    -0.181177
# 2 -0.073001 -0.253146        0.0            0.0    -0.229009    -0.181177
# 3 -0.073001 -0.253146        0.0            0.0    -0.229009    -0.181177
# 4 -0.073001 -0.253146        0.0            0.0    -0.229009    -0.181177
#
#    IGF2BP2_mean  IGF2BP2_variance  NOTCH2_PCA  NOTCH2_LDA       ...         \
# 0           0.0               0.0    0.315317   -0.009725       ...
# 1           0.0               0.0    0.634513    0.409493       ...
# 2           0.0               0.0   -0.949195    1.280339       ...
# 3           0.0               0.0    1.081059   -1.659938       ...
# 4           0.0               0.0    0.315317   -0.009725       ...
#
#    PPARG_mean  PPARG_variance  ZFAND6_PCA  ZFAND6_LDA  ZFAND6_mean  \
# 0         0.0             0.0   -0.218702   -0.489841          0.0
# 1         0.0             0.0    1.780863    4.051640          1.0
# 2         0.0             0.0   -0.218702   -0.489841          0.0
# 3         0.0             0.0   -0.218702   -0.489841          0.0
# 4         0.0             0.0    0.781081    1.780900          0.5
#
#    ZFAND6_variance  CDKAL1_PCA  CDKAL1_LDA  CDKAL1_mean  CDKAL1_variance
# 0             0.00   -0.272613    0.051311     0.333333         0.444444
# 1             1.00   -1.352588    0.737521     0.444444         0.691358
# 2             0.00   -0.478563   -0.776670     0.444444         0.469136
# 3             0.00   -0.713995    0.880211     0.222222         0.395062
# 4             0.25   -0.855654    0.087939     0.444444         0.469136
#
# [5 rows x 80 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(dataset_risk_genes, dataset['labels'], test_size = 0.3)

# Random Forest Model
rf_model = ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
           max_depth=None, max_features=None, max_leaf_nodes=20,
           min_impurity_decrease=0.0, min_impurity_split=None,
           min_samples_leaf=1, min_samples_split=2,
           min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
           oob_score=False, random_state=None, verbose=0, warm_start=False)
rf_model.fit(X_train, y_train)

# To save model
#joblib.dump(rf_model, '../../data/rf_model.pkl') 

# Predicting
# y_predicted = rf_model.predict(X_test)
y_predicted = cross_val_predict(rf_model, X_test, y_test, cv=5)
# print(confusion_matrix(y_test, y_predicted))

print('F1-score: ' + str(f1_score(y_test, y_predicted, average = 'micro')))

# Saving f1 score and all indexes
importances = rf_model.feature_importances_
importances_indexes = np.argsort(importances)[::-1]
importances_indexes = importances_indexes[0:10]
# Out:
# F1-score: 0.8333333333333334

# %% [markdown]
# # 1. Defining best parameters for only risk genes classifiers

# %%
param_grid = [
    {'n_estimators': [25, 50, 75, 100], 'max_features':[None], 'criterion': ['gini'],
     'min_samples_leaf':[1,2,3,5,10], 'min_samples_split':[2,4,5,8,10],
     'max_leaf_nodes': [2, 20, 50, 75, 100], 'n_jobs':[-1], 'bootstrap': [False]},
    {'n_estimators': [25, 50, 75, 100], 'max_features':[None], 'criterion': ['entropy'], 
     'min_samples_leaf':[1,2,3,5,10], 'min_samples_split':[2,4,5,8,10],
     'max_leaf_nodes': [2, 20, 50, 75, 100], 'n_jobs':[-1], 'bootstrap': [False]},
]

extra_class = ExtraTreesClassifier()
grid_search = GridSearchCV(extra_class, param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(X_train, y_train)

grid_search.best_estimator_
# Out:
# ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#            max_depth=None, max_features=None, max_leaf_nodes=50,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=3, min_samples_split=10,
#            min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=-1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
feature_importances = grid_search.best_estimator_.feature_importances_
sorted(zip(feature_importances, risk_features), reverse=True)
# Out:
# [(0.3003876742759069, 'GCK_LDA'),
#  (0.07888130312173368, 'KCNQ1_LDA'),
#  (0.06605648454644202, 'ADAMTS9_LDA'),
#  (0.06523710463071379, 'KCNQ1_LDA'),
#  (0.06244633835786666, 'WFS1_LDA'),
#  (0.020762128222743353, 'NOTCH2_LDA'),
#  (0.016358114964701964, 'NOTCH2_mean'),
#  (0.01625452798399663, 'NOTCH2_PCA'),
#  (0.014170525743576568, 'WFS1_mean'),
#  (0.014169212646935624, 'CDKAL1_PCA'),
#  (0.013621749718323839, 'THADA_LDA'),
#  (0.01309847629342091, 'PRC1_mean'),
#  (0.01292772814315217, 'IGF2BP2_mean'),
#  (0.012797758892638574, 'NOTCH2_variance'),
#  (0.012466446660996831, 'TLE4_variance'),
#  (0.012411015561411873, 'ZFAND6_PCA'),
#  (0.01154453495715563, 'TLE4_mean'),
#  (0.01024501724738283, 'THADA_PCA'),
#  (0.01021866894475044, 'ADCY5_LDA'),
#  (0.009960615806320253, 'ADAMTS9_PCA'),
#  (0.008902421304657673, 'WFS1_variance'),
#  (0.008767559505172022, 'PRC1_variance'),
#  (0.008735827934869649, 'GCK_PCA'),
#  (0.008214490405443853, 'ADAMTS9_mean'),
#  (0.008021113575278583, 'ADCY5_PCA'),
#  (0.007611271068206418, 'GCK_variance'),
#  (0.0074633628741039675, 'IGF2BP2_variance'),
#  (0.0072678666432874905, 'THADA_mean'),
#  (0.007167905762896675, 'IGF2BP2_PCA'),
#  (0.006250898952715056, 'PRC1_PCA'),
#  (0.005929958994950274, 'ADCY5_mean'),
#  (0.005834124247432008, 'TLE4_PCA'),
#  (0.005605060014340451, 'ZFAND6_LDA'),
#  (0.005565148965154622, 'KCNQ1_mean'),
#  (0.00547325858511903, 'PPARG_LDA'),
#  (0.005400037542637816, 'FTO_LDA'),
#  (0.005378063455003443, 'FTO_variance'),
#  (0.005164073726327572, 'KCNQ1_PCA'),
#  (0.0050944382895807576, 'JAZF1_PCA'),
#  (0.004976259859462207, 'ADAMTS9_variance'),
#  (0.00491029688970581, 'KCNQ1_PCA'),
#  (0.004717443391848512, 'KCNQ1_mean'),
#  (0.004573622487743534, 'GCKR_PCA'),
#  (0.004536533381884972, 'ADCY5_variance'),
#  (0.004524514024949715, 'CDKAL1_mean'),
#  (0.004506304754601369, 'KCNQ1_variance'),
#  (0.003983545936925375, 'FTO_mean'),
#  (0.0038990659517059924, 'FTO_PCA'),
#  (0.0038332020196204853, 'GCK_mean'),
#  (0.0037421104198823284, 'WFS1_PCA'),
#  (0.0037234410093211585, 'CDKAL1_variance'),
#  (0.0035452811170377223, 'KCNQ1_variance'),
#  (0.003501561847154561, 'CDKAL1_LDA'),
#  (0.0032446392596456653, 'GCKR_mean'),
#  (0.0030790682060170952, 'JAZF1_mean'),
#  (0.002931696557091045, 'IGF2BP2_LDA'),
#  (0.00285266049386515, 'JAZF1_LDA'),
#  (0.0028462317716310102, 'HMGA2_LDA'),
#  (0.0024514970541875142, 'HMGA2_mean'),
#  (0.0023408552843821894, 'ZFAND6_mean'),
#  (0.002091598408464243, 'GCKR_LDA'),
#  (0.0020194336334176314, 'TLE4_LDA'),
#  (0.001936943676592259, 'PPARG_variance'),
#  (0.0017663519504781844, 'HMGA2_PCA'),
#  (0.0015546291620602165, 'PPARG_PCA'),
#  (0.0013432330572544062, 'PRC1_LDA'),
#  (0.0013212400618458826, 'JAZF1_variance'),
#  (0.00120800165397955, 'PPARG_mean'),
#  (0.001062544071835977, 'GCKR_LDA'),
#  (0.0009823546888683905, 'GCKR_PCA'),
#  (0.0009724614744925056, 'ZFAND6_variance'),
#  (0.0008410578786904116, 'GCKR_mean'),
#  (0.0007849784158576576, 'GCKR_variance'),
#  (0.0007704409859464297, 'GCKR_variance'),
#  (0.0007625905942049884, 'THADA_variance'),
#  (0.0, 'HMGA2_variance'),
#  (0.0, 'DUSP9_variance'),
#  (0.0, 'DUSP9_mean'),
#  (0.0, 'DUSP9_PCA'),
#  (0.0, 'DUSP9_LDA')]

# %%
# from: http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
y_predicted = grid_search.best_estimator_.predict(X_test)
print('F1-score: ' + str(f1_score(y_test, y_predicted, average = 'micro')))
cnf_matrix = confusion_matrix(y_test, y_predicted)

plt.figure()
plot_confusion_matrix(cnf_matrix, classes=['control','T2D case'],
                      title='Confusion matrix')
# Out:
# F1-score: 0.8518518518518519
# <img src="data:image/png;base64,..." width="640">
# Confusion matrix, without normalization
# [[31  4]
#  [ 4 15]]

# %% [markdown]
# # 1.1 Using only the top 25 features

# %%
top_features = sorted(zip(feature_importances, risk_features), reverse=True)
top_features_25 = top_features[0:40]
top_features_25 = [x[1] for x in top_features_25]

# %%
X_train, X_test, y_train, y_test = train_test_split(dataset_risk_genes[top_features_25], dataset['labels'], test_size = 0.3)

param_grid = [
    {'n_estimators': [50, 75, 100], 'max_features':[None], 'criterion': ['gini'], 'max_leaf_nodes': [2, 20, 50, 75, 100, 125, 150], 'n_jobs':[-1], 'bootstrap': [False]},
    {'n_estimators': [50, 75, 100], 'max_features':[None], 'criterion': ['entropy'], 'max_leaf_nodes': [2, 20, 50, 75, 100, 125, 150], 'n_jobs':[-1], 'bootstrap': [False]},
]

extra_class = ExtraTreesClassifier()
grid_search = GridSearchCV(extra_class, param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(X_train, y_train)

grid_search.best_estimator_
# Out:
# ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#            max_depth=None, max_features=None, max_leaf_nodes=100,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
y_predicted = grid_search.best_estimator_.predict(X_test)
print('F1-score: ' + str(f1_score(y_test, y_predicted, average = 'micro')))
cnf_matrix = confusion_matrix(y_test, y_predicted)

plt.figure()
plot_confusion_matrix(cnf_matrix, classes=['control','T2D case'],
                      title='Confusion matrix')
# Out:
# F1-score: 0.8333333333333334
# <img src="data:image/png;base64,..." width="640">
# Confusion matrix, without normalization
# [[27  2]
#  [ 7 18]]

# %%
grid_search.best_estimator_
# Out:
# ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#            max_depth=None, max_features=None, max_leaf_nodes=100,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
def mean(numbers):
    return float(sum(numbers)) / max(len(numbers), 1)

# %% [markdown]
# # 1.2 Average for 100 runs with best parameters (only risk genes)

# %%
# Run several classifiers and find wich variants appear more

#Classifiers:
'''
CLASSIFIER 1
ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
           max_depth=None, max_features=None, max_leaf_nodes=50,
           min_impurity_decrease=0.0, min_impurity_split=None,
           min_samples_leaf=3, min_samples_split=10,
           min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=-1,
           oob_score=False, random_state=None, verbose=0, warm_start=False)

average accuracy: 0.74
average f1-score: 0.62

CLASSIFIER 2
ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='entropy',
           max_depth=None, max_features=None, max_leaf_nodes=50,
           min_impurity_decrease=0.0, min_impurity_split=None,
           min_samples_leaf=3, min_samples_split=10,
           min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=-1,
           oob_score=False, random_state=None, verbose=0, warm_start=False)

average accuracy: 
average f1-score: 0.74

CLASSIFIER 3
ExtraTreesClassifier(n_estimators=50, n_jobs=-1)

average f1-score: 0.68


'''


f1_scores = []
accuracies = []
recalls = []
top_variants = np.array([])
dataset_list = list(dataset_risk_genes)
for run in range(0, 100):
    # Dividing train and test
    X_train, X_test, y_train, y_test = train_test_split(dataset_risk_genes, dataset['labels'], test_size = 0.3)

    print('Fitting model number: '  + str(run))

    # Random Forest Model
    rf_model = ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
           max_depth=None, max_features=None, max_leaf_nodes=50,
           min_samples_leaf=3, min_samples_split=10,
           min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=-1,
           oob_score=False, random_state=None, verbose=0, warm_start=False)
    rf_model.fit(X_train, y_train)

    # To save model
    #joblib.dump(rf_model, '../../data/rf_model.pkl') 

    print('Predicting...')

    # Predicting
    # y_predicted = rf_model.predict(X_test)
    y_predicted = cross_val_predict(rf_model, X_test, y_test, cv=5)
    # print(confusion_matrix(y_test, y_predicted))

    print('F1-score: ' + str(f1_score(y_test, y_predicted)) + '\nAccuracy: ' + \
         str(accuracy_score(y_pred = y_predicted, y_true = y_test)) + \
         '\nRecall: ' + str(recall_score(y_true=y_test, y_pred=y_predicted)))
    
    f1_scores.append(f1_score(y_test, y_predicted))
    accuracies.append(accuracy_score(y_pred = y_predicted, y_true = y_test))
    recalls.append(recall_score(y_true=y_test, y_pred=y_predicted))

# Results and important features
f1s = mean(f1_scores)
accuracy_mean = mean(accuracies)
recall_mean = mean(recalls)
print('Final f1 score: ' + str(f1s) + '\nFinal Accuraccy: ' + str(accuracy_mean))
frequencies = Counter(top_variants)
# Out:
# Fitting model number: 0
# Predicting...
# F1-score: 0.571428571429
# Accuracy: 0.777777777778
# Recall: 0.444444444444
# Fitting model number: 1
# Predicting...
# F1-score: 0.48275862069
# Accuracy: 0.722222222222
# Recall: 0.388888888889
# Fitting model number: 2
# Predicting...
# F1-score: 0.68085106383
# Accuracy: 0.722222222222
# Recall: 0.666666666667
# Fitting model number: 3
# Predicting...
# F1-score: 0.5
# Accuracy: 0.740740740741
# Recall: 0.368421052632
# Fitting model number: 4
# Predicting...
# F1-score: 0.577777777778
# Accuracy: 0.648148148148
# Recall: 0.52
# Fitting model number: 5
# Predicting...
# F1-score: 0.615384615385
# Accuracy: 0.722222222222
# Recall: 0.521739130435
# Fitting model number: 6
# Predicting...
# F1-score: 0.648648648649
# Accuracy: 0.759259259259
# Recall: 0.571428571429
# Fitting model number: 7
# Predicting...
# F1-score: 0.625
# Accuracy: 0.777777777778
# Recall: 0.588235294118
# Fitting model number: 8
# Predicting...
# F1-score: 0.68
# Accuracy: 0.703703703704
# Recall: 0.68
# Fitting model number: 9
# Predicting...
# F1-score: 0.666666666667
# Accuracy: 0.777777777778
# Recall: 0.6
# Fitting model number: 10
# Predicting...
# F1-score: 0.736842105263
# Accuracy: 0.814814814815
# Recall: 0.666666666667
# Fitting model number: 11
# Predicting...
# F1-score: 0.5625
# Accuracy: 0.740740740741
# Recall: 0.45
# Fitting model number: 12
# Predicting...
# F1-score: 0.526315789474
# Accuracy: 0.666666666667
# Recall: 0.47619047619
# Fitting model number: 13
# Predicting...
# F1-score: 0.682926829268
# Accuracy: 0.759259259259
# Recall: 0.583333333333
# Fitting model number: 14
# Predicting...
# F1-score: 0.588235294118
# Accuracy: 0.740740740741
# Recall: 0.5
# Fitting model number: 15
# Predicting...
# F1-score: 0.717948717949
# Accuracy: 0.796296296296
# Recall: 0.636363636364
# Fitting model number: 16
# Predicting...
# F1-score: 0.628571428571
# Accuracy: 0.759259259259
# Recall: 0.55
# Fitting model number: 17
# Predicting...
# F1-score: 0.702702702703
# Accuracy: 0.796296296296
# Recall: 0.65
# Fitting model number: 18
# Predicting...
# F1-score: 0.846153846154
# Accuracy: 0.851851851852
# Recall: 0.88
# Fitting model number: 19
# Predicting...
# F1-score: 0.628571428571
# Accuracy: 0.759259259259
# Recall: 0.55
# Fitting model number: 20
# Predicting...
# F1-score: 0.645161290323
# Accuracy: 0.796296296296
# Recall: 0.588235294118
# Fitting model number: 21
# Predicting...
# F1-score: 0.461538461538
# Accuracy: 0.740740740741
# Recall: 0.352941176471
# Fitting model number: 22
# Predicting...
# F1-score: 0.615384615385
# Accuracy: 0.62962962963
# Recall: 0.615384615385
# Fitting model number: 23
# Predicting...
# F1-score: 0.558139534884
# Accuracy: 0.648148148148
# Recall: 0.5
# Fitting model number: 24
# Predicting...
# F1-score: 0.514285714286
# Accuracy: 0.685185185185
# Recall: 0.409090909091
# Fitting model number: 25
# Predicting...
# F1-score: 0.708333333333
# Accuracy: 0.740740740741
# Recall: 0.739130434783
# Fitting model number: 26
# Predicting...
# F1-score: 0.761904761905
# Accuracy: 0.814814814815
# Recall: 0.695652173913
# Fitting model number: 27
# Predicting...
# F1-score: 0.444444444444
# Accuracy: 0.62962962963
# Recall: 0.380952380952
# Fitting model number: 28
# Predicting...
# F1-score: 0.666666666667
# Accuracy: 0.740740740741
# Recall: 0.608695652174
# Fitting model number: 29
# Predicting...
# F1-score: 0.6
# Accuracy: 0.777777777778
# Recall: 0.473684210526
# Fitting model number: 30
# Predicting...
# F1-score: 0.685714285714
# Accuracy: 0.796296296296
# Recall: 0.571428571429
# Fitting model number: 31
# Predicting...
# F1-score: 0.685714285714
# Accuracy: 0.796296296296
# Recall: 0.631578947368
# Fitting model number: 32
# Predicting...
# F1-score: 0.636363636364
# Accuracy: 0.703703703704
# Recall: 0.608695652174
# Fitting model number: 33
# Predicting...
# F1-score: 0.7
# Accuracy: 0.777777777778
# Recall: 0.666666666667
# Fitting model number: 34
# Predicting...
# F1-score: 0.48
# Accuracy: 0.759259259259
# Recall: 0.375
# Fitting model number: 35
# Predicting...
# F1-score: 0.651162790698
# Accuracy: 0.722222222222
# Recall: 0.608695652174
# Fitting model number: 36
# Predicting...
# F1-score: 0.565217391304
# Accuracy: 0.62962962963
# Recall: 0.5
# Fitting model number: 37
# Predicting...
# F1-score: 0.734693877551
# Accuracy: 0.759259259259
# Recall: 0.72
# Fitting model number: 38
# Predicting...
# F1-score: 0.756756756757
# Accuracy: 0.833333333333
# Recall: 0.7
# Fitting model number: 39
# Predicting...
# F1-score: 0.606060606061
# Accuracy: 0.759259259259
# Recall: 0.526315789474
# Fitting model number: 40
# Predicting...
# F1-score: 0.541666666667
# Accuracy: 0.592592592593
# Recall: 0.52
# Fitting model number: 41
# Predicting...
# F1-score: 0.844444444444
# Accuracy: 0.87037037037
# Recall: 0.826086956522
# Fitting model number: 42
# Predicting...
# F1-score: 0.540540540541
# Accuracy: 0.685185185185
# Recall: 0.454545454545
# Fitting model number: 43
# Predicting...
# F1-score: 0.75
# Accuracy: 0.814814814815
# Recall: 0.681818181818
# Fitting model number: 44
# Predicting...
# F1-score: 0.754716981132
# Accuracy: 0.759259259259
# Recall: 0.740740740741
# Fitting model number: 45
# Predicting...
# F1-score: 0.717948717949
# Accuracy: 0.796296296296
# Recall: 0.608695652174
# Fitting model number: 46
# Predicting...
# F1-score: 0.611111111111
# Accuracy: 0.740740740741
# Recall: 0.55
# Fitting model number: 47
# Predicting...
# F1-score: 0.666666666667
# Accuracy: 0.777777777778
# Recall: 0.571428571429
# Fitting model number: 48
# Predicting...
# F1-score: 0.5625
# Accuracy: 0.740740740741
# Recall: 0.473684210526
# Fitting model number: 49
# Predicting...
# F1-score: 0.230769230769
# Accuracy: 0.62962962963
# Recall: 0.176470588235
# Fitting model number: 50
# Predicting...
# F1-score: 0.514285714286
# Accuracy: 0.685185185185
# Recall: 0.391304347826
# Fitting model number: 51
# Predicting...
# F1-score: 0.628571428571
# Accuracy: 0.759259259259
# Recall: 0.647058823529
# Fitting model number: 52
# Predicting...
# F1-score: 0.875
# Accuracy: 0.888888888889
# Recall: 0.84
# Fitting model number: 53
# Predicting...
# F1-score: 0.666666666667
# Accuracy: 0.777777777778
# Recall: 0.6
# Fitting model number: 54
# Predicting...
# F1-score: 0.551724137931
# Accuracy: 0.759259259259
# Recall: 0.444444444444
# Fitting model number: 55
# Predicting...
# F1-score: 0.679245283019
# Accuracy: 0.685185185185
# Recall: 0.692307692308
# Fitting model number: 56
# Predicting...
# F1-score: 0.763636363636
# Accuracy: 0.759259259259
# Recall: 0.75
# Fitting model number: 57
# Predicting...
# F1-score: 0.56
# Accuracy: 0.796296296296
# Recall: 0.4375
# Fitting model number: 58
# Predicting...
# F1-score: 0.315789473684
# Accuracy: 0.759259259259
# Recall: 0.2
# Fitting model number: 59
# Predicting...
# F1-score: 0.486486486486
# Accuracy: 0.648148148148
# Recall: 0.45
# Fitting model number: 60
# Predicting...
# F1-score: 0.368421052632
# Accuracy: 0.555555555556
# Recall: 0.35
# Fitting model number: 61
# Predicting...
# F1-score: 0.736842105263
# Accuracy: 0.814814814815
# Recall: 0.636363636364
# Fitting model number: 62
# Predicting...
# F1-score: 0.666666666667
# Accuracy: 0.777777777778
# Recall: 0.571428571429
# Fitting model number: 63
# Predicting...
# F1-score: 0.790697674419
# Accuracy: 0.833333333333
# Recall: 0.772727272727
# Fitting model number: 64
# Predicting...
# F1-score: 0.551724137931
# Accuracy: 0.759259259259
# Recall: 0.470588235294
# Fitting model number: 65
# Predicting...
# F1-score: 0.5
# Accuracy: 0.666666666667
# Recall: 0.391304347826
# Fitting model number: 66
# Predicting...
# F1-score: 0.648648648649
# Accuracy: 0.759259259259
# Recall: 0.6
# Fitting model number: 67
# Predicting...
# F1-score: 0.5
# Accuracy: 0.62962962963
# Recall: 0.434782608696
# Fitting model number: 68
# Predicting...
# F1-score: 0.363636363636
# Accuracy: 0.611111111111
# Recall: 0.272727272727
# Fitting model number: 69
# Predicting...
# F1-score: 0.682926829268
# Accuracy: 0.759259259259
# Recall: 0.608695652174
# Fitting model number: 70
# Predicting...
# F1-score: 0.65
# Accuracy: 0.740740740741
# Recall: 0.65
# Fitting model number: 71
# Predicting...
# F1-score: 0.7
# Accuracy: 0.777777777778
# Recall: 0.636363636364
# Fitting model number: 72
# Predicting...
# F1-score: 0.380952380952
# Accuracy: 0.759259259259
# Recall: 0.285714285714
# Fitting model number: 73
# Predicting...
# F1-score: 0.709677419355
# Accuracy: 0.833333333333
# Recall: 0.578947368421
# Fitting model number: 74
# Predicting...
# F1-score: 0.702702702703
# Accuracy: 0.796296296296
# Recall: 0.619047619048
# Fitting model number: 75
# Predicting...
# F1-score: 0.666666666667
# Accuracy: 0.759259259259
# Recall: 0.590909090909
# Fitting model number: 76
# Predicting...
# F1-score: 0.296296296296
# Accuracy: 0.648148148148
# Recall: 0.222222222222
# Fitting model number: 77
# Predicting...
# F1-score: 0.514285714286
# Accuracy: 0.685185185185
# Recall: 0.45
# Fitting model number: 78
# Predicting...
# F1-score: 0.666666666667
# Accuracy: 0.777777777778
# Recall: 0.571428571429
# Fitting model number: 79
# Predicting...
# F1-score: 0.666666666667
# Accuracy: 0.777777777778
# Recall: 0.571428571429
# Fitting model number: 80
# Predicting...
# F1-score: 0.529411764706
# Accuracy: 0.703703703704
# Recall: 0.428571428571
# Fitting model number: 81
# Predicting...
# F1-score: 0.744186046512
# Accuracy: 0.796296296296
# Recall: 0.761904761905
# Fitting model number: 82
# Predicting...
# F1-score: 0.722222222222
# Accuracy: 0.814814814815
# Recall: 0.65
# Fitting model number: 83
# Predicting...
# F1-score: 0.782608695652
# Accuracy: 0.814814814815
# Recall: 0.72
# Fitting model number: 84
# Predicting...
# F1-score: 0.791666666667
# Accuracy: 0.814814814815
# Recall: 0.791666666667
# Fitting model number: 85
# Predicting...
# F1-score: 0.739130434783
# Accuracy: 0.777777777778
# Recall: 0.68
# Fitting model number: 86
# Predicting...
# F1-score: 0.893617021277
# Accuracy: 0.907407407407
# Recall: 0.875
# Fitting model number: 87
# Predicting...
# F1-score: 0.484848484848
# Accuracy: 0.685185185185
# Recall: 0.363636363636
# Fitting model number: 88
# Predicting...
# F1-score: 0.645161290323
# Accuracy: 0.796296296296
# Recall: 0.555555555556
# Fitting model number: 89
# Predicting...
# F1-score: 0.514285714286
# Accuracy: 0.685185185185
# Recall: 0.409090909091
# Fitting model number: 90
# Predicting...
# F1-score: 0.6
# Accuracy: 0.777777777778
# Recall: 0.529411764706
# Fitting model number: 91
# Predicting...
# F1-score: 0.512820512821
# Accuracy: 0.648148148148
# Recall: 0.5
# Fitting model number: 92
# Predicting...
# F1-score: 0.608695652174
# Accuracy: 0.833333333333
# Recall: 0.4375
# Fitting model number: 93
# Predicting...
# F1-score: 0.533333333333
# Accuracy: 0.740740740741
# Recall: 0.444444444444
# Fitting model number: 94
# Predicting...
# F1-score: 0.533333333333
# Accuracy: 0.740740740741
# Recall: 0.4
# Fitting model number: 95
# Predicting...
# F1-score: 0.588235294118
# Accuracy: 0.740740740741
# Recall: 0.5
# Fitting model number: 96
# Predicting...
# F1-score: 0.631578947368
# Accuracy: 0.740740740741
# Recall: 0.6
# Fitting model number: 97
# Predicting...
# F1-score: 0.684210526316
# Accuracy: 0.777777777778
# Recall: 0.65
# Fitting model number: 98
# Predicting...
# F1-score: 0.744186046512
# Accuracy: 0.796296296296
# Recall: 0.64
# Fitting model number: 99
# Predicting...
# F1-score: 0.590909090909
# Accuracy: 0.666666666667
# Recall: 0.565217391304
# Final f1 score: 0.6204651554319826
# Final Accuraccy: 0.7468518518518521

# %% [markdown]
# # 2. Testing with the full dataset

# %%
pre_X = dataset.drop('labels', axis = 1)
X_train, X_test, y_train, y_test = train_test_split(pre_X, dataset['labels'], test_size = 0.3)

param_grid = [
    {'n_estimators': [25, 50, 75, 100], 'max_features':[None], 'criterion': ['gini'],
     'min_samples_leaf':[1,2,3,5,10], 'min_samples_split':[2,4,5,8,10],
     'max_leaf_nodes': [2, 20, 50, 75, 100], 'n_jobs':[-1], 'bootstrap': [False]},
    {'n_estimators': [25, 50, 75, 100], 'max_features':[None], 'criterion': ['entropy'], 
     'min_samples_leaf':[1,2,3,5,10], 'min_samples_split':[2,4,5,8,10],
     'max_leaf_nodes': [2, 20, 50, 75, 100], 'n_jobs':[-1], 'bootstrap': [False]},
]

extra_class_full = ExtraTreesClassifier()
grid_search_full = GridSearchCV(extra_class_full, param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search_full.fit(X_train, y_train)

grid_search_full.best_estimator_
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-1f597131e5ea> in <module>()
#      13 extra_class_full = ExtraTreesClassifier()
#      14 grid_search_full = GridSearchCV(extra_class_full, param_grid, cv=5, scoring='neg_mean_squared_error')
# ---> 15 grid_search_full.fit(X_train, y_train)
#      16
#      17 grid_search_full.best_estimator_
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups)
#     943             train/test set.
#     944         """
# --> 945         return self._fit(X, y, groups, ParameterGrid(self.param_grid))
#     946
#     947
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_search.py in _fit(self, X, y, groups, parameter_iterable)
#     562                                   return_times=True, return_parameters=True,
#     563                                   error_score=self.error_score)
# --> 564           for parameters in parameter_iterable
#     565           for train, test in cv_iter)
#     566
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     756             # was dispatched. In particular this covers the edge
#     757             # case of Parallel used with an exhausted iterator.
# --> 758             while self.dispatch_one_batch(iterator):
#     759                 self._iterating = True
#     760             else:
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     606                 return False
#     607             else:
# --> 608                 self._dispatch(tasks)
#     609                 return True
#     610
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     569         dispatch_timestamp = time.time()
#     570         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 571         job = self._backend.apply_async(batch, callback=cb)
#     572         self._jobs.append(job)
#     573
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     107     def apply_async(self, func, callback=None):
#     108         """Schedule a func to be run"""
# --> 109         result = ImmediateResult(func)
#     110         if callback:
#     111             callback(result)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     324         # Don't delay the application, to avoid keeping the input
#     325         # arguments in memory
# --> 326         self.results = batch()
#     327
#     328     def get(self):
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, error_score)
#     261         score_time = time.time() - start_time - fit_time
#     262         if return_train_score:
# --> 263             train_score = _score(estimator, X_train, y_train, scorer)
#     264
#     265     if verbose > 2:
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in _score(estimator, X_test, y_test, scorer)
#     286         score = scorer(estimator, X_test)
#     287     else:
# --> 288         score = scorer(estimator, X_test, y_test)
#     289     if hasattr(score, 'item'):
#     290         try:
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/metrics/scorer.py in __call__(self, estimator, X, y_true, sample_weight)
#      89         super(_PredictScorer, self).__call__(estimator, X, y_true,
#      90                                              sample_weight=sample_weight)
# ---> 91         y_pred = estimator.predict(X)
#      92         if sample_weight is not None:
#      93             return self._sign * self._score_func(y_true, y_pred,
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py in predict(self, X)
#     532             The predicted classes.
#     533         """
# --> 534         proba = self.predict_proba(X)
#     535
#     536         if self.n_outputs_ == 1:
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py in predict_proba(self, X)
#     581             delayed(parallel_helper)(e, 'predict_proba', X,
#     582                                       check_input=False)
# --> 583             for e in self.estimators_)
#     584
#     585         # Reduce
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     774         finally:
#     775             if not self._managed_backend:
# --> 776                 self._terminate_backend()
#     777             self._jobs = list()
#     778         output = self._output
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in _terminate_backend(self)
#     551     def _terminate_backend(self):
#     552         if self._backend is not None:
# --> 553             self._backend.terminate()
#     554
#     555     def _dispatch(self, batch):
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in terminate(self)
#     132         if self._pool is not None:
#     133             self._pool.close()
# --> 134             self._pool.terminate()  # terminate does a join()
#     135             self._pool = None
#     136
#
# ~/anaconda3/lib/python3.6/multiprocessing/pool.py in terminate(self)
#     539         self._state = TERMINATE
#     540         self._worker_handler._state = TERMINATE
# --> 541         self._terminate()
#     542
#     543     def join(self):
#
# ~/anaconda3/lib/python3.6/multiprocessing/util.py in __call__(self, wr, _finalizer_registry, sub_debug, getpid)
#     184                 sub_debug('finalizer calling %s with args %s and kwargs %s',
#     185                           self._callback, self._args, self._kwargs)
# --> 186                 res = self._callback(*self._args, **self._kwargs)
#     187             self._weakref = self._callback = self._args = \
#     188                             self._kwargs = self._key = None
#
# ~/anaconda3/lib/python3.6/multiprocessing/pool.py in _terminate_pool(cls, taskqueue, inqueue, outqueue, pool, worker_handler, task_handler, result_handler, cache)
#     580         util.debug('joining worker handler')
#     581         if threading.current_thread() is not worker_handler:
# --> 582             worker_handler.join()
#     583
#     584         # Terminate workers which haven't already finished.
#
# ~/anaconda3/lib/python3.6/threading.py in join(self, timeout)
#    1054
#    1055         if timeout is None:
# -> 1056             self._wait_for_tstate_lock()
#    1057         else:
#    1058             # the behavior of a negative timeout isn't documented, but
#
# ~/anaconda3/lib/python3.6/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1070         if lock is None:  # already determined that the C code is done
#    1071             assert self._is_stopped
# -> 1072         elif lock.acquire(block, timeout):
#    1073             lock.release()
#    1074             self._stop()
#
# KeyboardInterrupt:

# %%
feature_importances = grid_search_full.best_estimator_.feature_importances_
sorted(zip(feature_importances, list(dataset)), reverse=True)
# Out:
# [(0.15863306529747578, 'EVPLL_LDA'),
#  (0.1190207033855199, 'EVPLL_PCA'),
#  (0.11077725896940843, 'FAM71E2_LDA'),
#  (0.0655365774602478, 'FAM71E2_mean'),
#  (0.06110208621203839, 'FAM71E2_PCA'),
#  (0.041649637040476944, 'MAGEB3_variance'),
#  (0.030874866507669855, 'TAB3_mean'),
#  (0.028893464585997872, 'TAB3_LDA'),
#  (0.027381810540270952, 'GPC4_PCA'),
#  (0.024760325462171676, 'EVPLL_mean'),
#  (0.022236787567358522, 'FAM120C_PCA'),
#  (0.01818144080567339, 'GPC4_mean'),
#  (0.01653289961173324, 'ECI1_mean'),
#  (0.016211873811216897, 'NGLY1_LDA'),
#  (0.01469771390058074, 'GPC4_LDA'),
#  (0.0140044512444493, 'ECI1_PCA'),
#  (0.013611192532162879, 'TAB3_PCA'),
#  (0.013114469462480974, 'GABRA3_LDA'),
#  (0.012659995547907199, 'SLC38A5_LDA'),
#  (0.01175156933469532, 'WFS1_LDA'),
#  (0.011055902429665304, 'ECI1_LDA'),
#  (0.009959633798203162, 'FAM120C_mean'),
#  (0.00965682491560716, 'FRMD7_LDA'),
#  (0.009447803025579802, 'THADA_mean'),
#  (0.008704332230462212, 'MAGEB3_LDA'),
#  (0.008230863750131424, 'NGLY1_mean'),
#  (0.007764206703116267, 'EVPLL_variance'),
#  (0.0077492742944972656, 'NGLY1_PCA'),
#  (0.0045494391465661236, 'GCK_LDA'),
#  (0.0044006315806139175, 'FAM120C_LDA'),
#  (0.004370943760014682, 'THADA_variance'),
#  (0.0042829563740130385, 'GCK_mean'),
#  (0.00349797620000139, 'SLC25A43_PCA'),
#  (0.0033442409189343124, 'PLS3_variance'),
#  (0.0029816022825311793, 'SLC25A43_LDA'),
#  (0.0029637861152713428, 'PRDX4_LDA'),
#  (0.0029163018655065597, 'KIF20B_LDA'),
#  (0.0027506609108575563, 'SERTM1_LDA'),
#  (0.002691233556545327, 'SERTM1_mean'),
#  (0.00248911758375914, 'ZC3H12B_LDA'),
#  (0.002276386753276334, 'RBBP7_PCA'),
#  (0.002180167379192644, 'MTSS1L_PCA'),
#  (0.00204308467728309, 'MTSS1L_mean'),
#  (0.0020289743934265208, 'GCKR_mean'),
#  (0.0019820846682989893, 'KIF20B_PCA'),
#  (0.0019414543305020437, 'EIF2S3_variance'),
#  (0.001918259454179752, 'ARSE_mean'),
#  (0.0018714976565620918, 'SMARCC2_PCA'),
#  (0.0018221971324211652, 'NUCB2_mean'),
#  (0.0018221971324211652, 'NUCB2_LDA'),
#  (0.0018131059987999477, 'GABRA3_mean'),
#  (0.0017794638331404377, 'ZC3H12B_variance'),
#  (0.0017205610253471653, 'TLR2_variance'),
#  (0.0016458229582982343, 'ARSE_variance'),
#  (0.0015729730826487493, 'PLS3_LDA'),
#  (0.0013921507353973528, 'MDFI_variance'),
#  (0.0013137110689458746, 'FRMD7_mean'),
#  (0.0013082268050596541, 'FTO_variance'),
#  (0.001214095101258241, 'WFS1_mean'),
#  (0.001210721829268278, 'NUCB2_PCA'),
#  (0.001175653128589812, 'SMIM10_LDA'),
#  (0.0011723711833086467, 'SMIM10_PCA'),
#  (0.0011361326724702364, 'STEAP1B_mean'),
#  (0.001124854402920459, 'NOTCH2_mean'),
#  (0.0011121564263174622, 'SMARCC2_LDA'),
#  (0.0011117524586278914, 'ARSE_PCA'),
#  (0.0010955177519907861, 'NOTCH2_variance'),
#  (0.001029629846079454, 'PMS2_variance'),
#  (0.0009701172517710134, 'NIPSNAP2_PCA'),
#  (0.0009539153780781782, 'SMARCC2_mean'),
#  (0.0009040902627201295, 'PMS2_mean'),
#  (0.0008918061125120888, 'THADA_PCA'),
#  (0.000865813945487977, 'RNF175_PCA'),
#  (0.0008099044942131799, 'SMIM10L2A_mean'),
#  (0.0008000300448522455, 'TLR2_PCA'),
#  (0.0007732591890725125, 'MDFI_LDA'),
#  (0.0006507985094289525, 'HSPD1_LDA'),
#  (0.0006378421755766903, 'IL12RB1_PCA'),
#  (0.0006351440572750591, 'ATP11C_mean'),
#  (0.0006313909775353834, 'OPN1LW_mean'),
#  (0.0006296283907749686, 'OPN1LW_PCA'),
#  (0.0006205668597230423, 'CD27_LDA'),
#  (0.0006065964433632154, 'OPN1LW_LDA'),
#  (0.0006044273624054696, 'ATP11C_LDA'),
#  (0.0006018747180077684, 'RNF175_mean'),
#  (0.00059913907203423, 'FTO_PCA'),
#  (0.000562314772511134, 'MBTPS2_mean'),
#  (0.0005552544258449597, 'CDKAL1_variance'),
#  (0.0005391255654324375, 'DKC1_mean'),
#  (0.0005359398610027267, 'RBBP7_mean'),
#  (0.000534443734930306, 'RBBP7_LDA'),
#  (0.0005098599526414688, 'VEGFD_LDA'),
#  (0.00047781897545830796, 'SLC39A4_LDA'),
#  (0.0004358622211445438, 'ZC3H12B_PCA'),
#  (0.0004318361591084072, 'FAM156B_variance'),
#  (0.00041612852257388205, 'KIF20B_mean'),
#  (0.0003575852018562533, 'STARD8_LDA'),
#  (0.0003575852018562533, 'MDFI_mean'),
#  (0.00035682856453266964, 'WFS1_variance'),
#  (0.00035682856453266964, 'PPARG_LDA'),
#  (0.0003361373285712907, 'PPARG_mean'),
#  (0.0003036669066588403, 'GCKR_variance'),
#  (0.0002499118873300137, 'MAGEA12_PCA'),
#  (0.00024140230173602217, 'MAGEB3_mean'),
#  (0.0, 'ZFP92_variance'),
#  (0.0, 'ZFP92_mean'),
#  (0.0, 'ZFP92_PCA'),
#  (0.0, 'ZFP92_LDA'),
#  (0.0, 'ZFAND6_variance'),
#  (0.0, 'ZFAND6_mean'),
#  (0.0, 'ZFAND6_PCA'),
#  (0.0, 'ZFAND6_LDA'),
#  (0.0, 'ZC3H7B_variance'),
#  (0.0, 'ZC3H7B_mean'),
#  (0.0, 'ZC3H7B_PCA'),
#  (0.0, 'ZC3H7B_LDA'),
#  (0.0, 'ZC3H12B_mean'),
#  (0.0, 'WFS1_PCA'),
#  (0.0, 'VEGFD_variance'),
#  (0.0, 'VEGFD_mean'),
#  (0.0, 'VEGFD_PCA'),
#  (0.0, 'URGCP-MRPS24_variance'),
#  (0.0, 'URGCP-MRPS24_mean'),
#  (0.0, 'URGCP-MRPS24_PCA'),
#  (0.0, 'URGCP-MRPS24_LDA'),
#  (0.0, 'TM4SF1_variance'),
#  (0.0, 'TM4SF1_mean'),
#  (0.0, 'TM4SF1_PCA'),
#  (0.0, 'TM4SF1_LDA'),
#  (0.0, 'TLR2_mean'),
#  (0.0, 'TLR2_LDA'),
#  (0.0, 'TLE4_variance'),
#  (0.0, 'TLE4_mean'),
#  (0.0, 'TLE4_PCA'),
#  (0.0, 'TLE4_LDA'),
#  (0.0, 'THADA_LDA'),
#  (0.0, 'TEX53_variance'),
#  (0.0, 'TEX53_mean'),
#  (0.0, 'TEX53_PCA'),
#  (0.0, 'TEX53_LDA'),
#  (0.0, 'TET1_variance'),
#  (0.0, 'TET1_mean'),
#  (0.0, 'TET1_PCA'),
#  (0.0, 'TET1_LDA'),
#  (0.0, 'TBC1D15_variance'),
#  (0.0, 'TBC1D15_mean'),
#  (0.0, 'TBC1D15_PCA'),
#  (0.0, 'TBC1D15_LDA'),
#  (0.0, 'TAC1_variance'),
#  (0.0, 'TAC1_mean'),
#  (0.0, 'TAC1_PCA'),
#  (0.0, 'TAC1_LDA'),
#  (0.0, 'TAB3_variance'),
#  (0.0, 'SYAP1_variance'),
#  (0.0, 'SYAP1_mean'),
#  (0.0, 'SYAP1_PCA'),
#  (0.0, 'SYAP1_LDA'),
#  (0.0, 'STEAP1B_variance'),
#  (0.0, 'STEAP1B_PCA'),
#  (0.0, 'STEAP1B_LDA'),
#  (0.0, 'STARD8_variance'),
#  (0.0, 'STARD8_mean'),
#  (0.0, 'STARD8_PCA'),
#  (0.0, 'SMS_variance'),
#  (0.0, 'SMS_mean'),
#  (0.0, 'SMS_PCA'),
#  (0.0, 'SMS_LDA'),
#  (0.0, 'SMIM36_variance'),
#  (0.0, 'SMIM36_mean'),
#  (0.0, 'SMIM36_PCA'),
#  (0.0, 'SMIM36_LDA'),
#  (0.0, 'SMIM10_variance'),
#  (0.0, 'SMIM10_mean'),
#  (0.0, 'SMIM10L2A_variance'),
#  (0.0, 'SMIM10L2A_PCA'),
#  (0.0, 'SMIM10L2A_LDA'),
#  (0.0, 'SMARCC2_variance'),
#  (0.0, 'SLC46A1_variance'),
#  (0.0, 'SLC46A1_mean'),
#  (0.0, 'SLC46A1_PCA'),
#  (0.0, 'SLC46A1_LDA'),
#  (0.0, 'SLC39A4_variance'),
#  (0.0, 'SLC39A4_mean'),
#  (0.0, 'SLC39A4_PCA'),
#  (0.0, 'SLC38A5_variance'),
#  (0.0, 'SLC38A5_mean'),
#  (0.0, 'SLC38A5_PCA'),
#  (0.0, 'SLC25A43_variance'),
#  (0.0, 'SLC25A43_mean'),
#  (0.0, 'SLC25A19_variance'),
#  (0.0, 'SLC25A19_mean'),
#  (0.0, 'SLC25A19_PCA'),
#  (0.0, 'SLC25A19_LDA'),
#  (0.0, 'SIX4_variance'),
#  (0.0, 'SIX4_mean'),
#  (0.0, 'SIX4_PCA'),
#  (0.0, 'SIX4_LDA'),
#  (0.0, 'SERTM1_variance'),
#  (0.0, 'SERTM1_PCA'),
#  (0.0, 'SEMA4A_variance'),
#  (0.0, 'SEMA4A_mean'),
#  (0.0, 'SEMA4A_PCA'),
#  (0.0, 'SEMA4A_LDA'),
#  (0.0, 'SELPLG_variance'),
#  (0.0, 'SELPLG_mean'),
#  (0.0, 'SELPLG_PCA'),
#  (0.0, 'SELPLG_LDA'),
#  (0.0, 'RRAGB_variance'),
#  (0.0, 'RRAGB_mean'),
#  (0.0, 'RRAGB_PCA'),
#  (0.0, 'RRAGB_LDA'),
#  (0.0, 'RNF175_variance'),
#  (0.0, 'RNF175_LDA'),
#  (0.0, 'RELT_variance'),
#  (0.0, 'RELT_mean'),
#  (0.0, 'RELT_PCA'),
#  (0.0, 'RELT_LDA'),
#  (0.0, 'RECQL4_variance'),
#  (0.0, 'RECQL4_mean'),
#  (0.0, 'RECQL4_PCA'),
#  (0.0, 'RECQL4_LDA'),
#  (0.0, 'RCOR3_variance'),
#  (0.0, 'RCOR3_mean'),
#  (0.0, 'RCOR3_PCA'),
#  (0.0, 'RCOR3_LDA'),
#  (0.0, 'RBBP7_variance'),
#  (0.0, 'RAB41_variance'),
#  (0.0, 'RAB41_mean'),
#  (0.0, 'RAB41_PCA'),
#  (0.0, 'RAB41_LDA'),
#  (0.0, 'PRRT3_variance'),
#  (0.0, 'PRRT3_mean'),
#  (0.0, 'PRRT3_PCA'),
#  (0.0, 'PRRT3_LDA'),
#  (0.0, 'PRR3_variance'),
#  (0.0, 'PRR3_mean'),
#  (0.0, 'PRR3_PCA'),
#  (0.0, 'PRR3_LDA'),
#  (0.0, 'PRKX_variance'),
#  (0.0, 'PRKX_mean'),
#  (0.0, 'PRKX_PCA'),
#  (0.0, 'PRKX_LDA'),
#  (0.0, 'PRDX4_variance'),
#  (0.0, 'PRDX4_mean'),
#  (0.0, 'PRDX4_PCA'),
#  (0.0, 'PRC1_variance'),
#  (0.0, 'PRC1_mean'),
#  (0.0, 'PRC1_PCA'),
#  (0.0, 'PRC1_LDA'),
#  (0.0, 'PPARG_variance'),
#  (0.0, 'PPARG_PCA'),
#  (0.0, 'PNMA6A_variance'),
#  (0.0, 'PNMA6A_mean'),
#  (0.0, 'PNMA6A_PCA'),
#  (0.0, 'PNMA6A_LDA'),
#  (0.0, 'PNMA5_variance'),
#  (0.0, 'PNMA5_mean'),
#  (0.0, 'PNMA5_PCA'),
#  (0.0, 'PNMA5_LDA'),
#  (0.0, 'PMS2_PCA'),
#  (0.0, 'PMS2_LDA'),
#  (0.0, 'PLS3_mean'),
#  (0.0, 'PLS3_PCA'),
#  (0.0, 'PLCD1_variance'),
#  (0.0, 'PLCD1_mean'),
#  (0.0, 'PLCD1_PCA'),
#  (0.0, 'PLCD1_LDA'),
#  (0.0, 'PIGA_variance'),
#  (0.0, 'PIGA_mean'),
#  (0.0, 'PIGA_PCA'),
#  (0.0, 'PIGA_LDA'),
#  (0.0, 'OR13J1_variance'),
#  (0.0, 'OR13J1_mean'),
#  (0.0, 'OR13J1_PCA'),
#  (0.0, 'OR13J1_LDA'),
#  (0.0, 'OR10H2_variance'),
#  (0.0, 'OR10H2_mean'),
#  (0.0, 'OR10H2_PCA'),
#  (0.0, 'OR10H2_LDA'),
#  (0.0, 'OPN1LW_variance'),
#  (0.0, 'NXT1_variance'),
#  (0.0, 'NXT1_mean'),
#  (0.0, 'NXT1_PCA'),
#  (0.0, 'NXT1_LDA'),
#  (0.0, 'NUCB2_variance'),
#  (0.0, 'NRIP1_variance'),
#  (0.0, 'NRIP1_mean'),
#  (0.0, 'NRIP1_PCA'),
#  (0.0, 'NRIP1_LDA'),
#  (0.0, 'NPPC_variance'),
#  (0.0, 'NPPC_mean'),
#  (0.0, 'NPPC_PCA'),
#  (0.0, 'NPPC_LDA'),
#  (0.0, 'NOTCH2_PCA'),
#  (0.0, 'NOTCH2_LDA'),
#  (0.0, 'NIPSNAP2_variance'),
#  (0.0, 'NIPSNAP2_mean'),
#  (0.0, 'NIPSNAP2_LDA'),
#  (0.0, 'NGLY1_variance'),
#  (0.0, 'NECTIN3_variance'),
#  (0.0, 'NECTIN3_mean'),
#  (0.0, 'NECTIN3_PCA'),
#  (0.0, 'NECTIN3_LDA'),
#  (0.0, 'NDUFB6_variance'),
#  (0.0, 'NDUFB6_mean'),
#  (0.0, 'NDUFB6_PCA'),
#  (0.0, 'NDUFB6_LDA'),
#  (0.0, 'NAXE_variance'),
#  (0.0, 'NAXE_mean'),
#  (0.0, 'NAXE_PCA'),
#  (0.0, 'NAXE_LDA'),
#  (0.0, 'MTSS1L_variance'),
#  (0.0, 'MTSS1L_LDA'),
#  (0.0, 'MSH5-SAPCD1_variance'),
#  (0.0, 'MSH5-SAPCD1_mean'),
#  (0.0, 'MSH5-SAPCD1_PCA'),
#  (0.0, 'MSH5-SAPCD1_LDA'),
#  (0.0, 'MPP5_variance'),
#  (0.0, 'MPP5_mean'),
#  (0.0, 'MPP5_PCA'),
#  (0.0, 'MPP5_LDA'),
#  (0.0, 'MDFI_PCA'),
#  (0.0, 'MBTPS2_variance'),
#  (0.0, 'MBTPS2_PCA'),
#  (0.0, 'MBTPS2_LDA'),
#  (0.0, 'MAGEB3_PCA'),
#  (0.0, 'MAGEA12_variance'),
#  (0.0, 'MAGEA12_mean'),
#  (0.0, 'MAGEA12_LDA'),
#  (0.0, 'MAGEA10_variance'),
#  (0.0, 'MAGEA10_mean'),
#  (0.0, 'MAGEA10_PCA'),
#  (0.0, 'MAGEA10_LDA'),
#  (0.0, 'LSM2_variance'),
#  (0.0, 'LSM2_mean'),
#  (0.0, 'LSM2_PCA'),
#  (0.0, 'LSM2_LDA'),
#  (0.0, 'KRBOX4_variance'),
#  (0.0, 'KRBOX4_mean'),
#  (0.0, 'KRBOX4_PCA'),
#  (0.0, 'KRBOX4_LDA'),
#  (0.0, 'KLHL15_variance'),
#  (0.0, 'KLHL15_mean'),
#  (0.0, 'KLHL15_PCA'),
#  (0.0, 'KLHL15_LDA'),
#  (0.0, 'KIF20B_variance'),
#  (0.0, 'KIDINS220_variance'),
#  (0.0, 'KIDINS220_mean'),
#  (0.0, 'KIDINS220_PCA'),
#  (0.0, 'KIDINS220_LDA'),
#  (0.0, 'KIAA1586_variance'),
#  (0.0, 'KIAA1586_mean'),
#  (0.0, 'KIAA1586_PCA'),
#  (0.0, 'KIAA1586_LDA'),
#  (0.0, 'KCNQ1_variance'),
#  (0.0, 'KCNQ1_mean'),
#  (0.0, 'KCNQ1_PCA'),
#  (0.0, 'KCNQ1_LDA'),
#  (0.0, 'JAZF1_variance'),
#  (0.0, 'JAZF1_mean'),
#  (0.0, 'JAZF1_PCA'),
#  (0.0, 'JAZF1_LDA'),
#  (0.0, 'IL12RB1_variance'),
#  (0.0, 'IL12RB1_mean'),
#  (0.0, 'IL12RB1_LDA'),
#  (0.0, 'IGF2BP2_variance'),
#  (0.0, 'IGF2BP2_mean'),
#  (0.0, 'IGF2BP2_PCA'),
#  (0.0, 'IGF2BP2_LDA'),
#  (0.0, 'HSPD1_variance'),
#  (0.0, 'HSPD1_mean'),
#  (0.0, 'HSPD1_PCA'),
#  (0.0, 'HMGA2_variance'),
#  (0.0, 'HMGA2_mean'),
#  (0.0, 'HMGA2_PCA'),
#  (0.0, 'HMGA2_LDA'),
#  (0.0, 'HIPK4_variance'),
#  (0.0, 'HIPK4_mean'),
#  (0.0, 'HIPK4_PCA'),
#  (0.0, 'HIPK4_LDA'),
#  (0.0, 'HDC_variance'),
#  (0.0, 'HDC_mean'),
#  (0.0, 'HDC_PCA'),
#  (0.0, 'HDC_LDA'),
#  (0.0, 'GSTZ1_variance'),
#  (0.0, 'GSTZ1_mean'),
#  (0.0, 'GSTZ1_PCA'),
#  (0.0, 'GSTZ1_LDA'),
#  (0.0, 'GPR160_variance'),
#  (0.0, 'GPR160_mean'),
#  (0.0, 'GPR160_PCA'),
#  (0.0, 'GPR160_LDA'),
#  (0.0, 'GPC4_variance'),
#  (0.0, 'GLS_variance'),
#  (0.0, 'GLS_mean'),
#  (0.0, 'GLS_PCA'),
#  (0.0, 'GLS_LDA'),
#  (0.0, 'GLRX2_variance'),
#  (0.0, 'GLRX2_mean'),
#  (0.0, 'GLRX2_PCA'),
#  (0.0, 'GLRX2_LDA'),
#  (0.0, 'GCK_variance'),
#  (0.0, 'GCK_PCA'),
#  (0.0, 'GCKR_PCA'),
#  (0.0, 'GCKR_LDA'),
#  (0.0, 'GABRA3_variance'),
#  (0.0, 'GABRA3_PCA'),
#  (0.0, 'FTO_mean'),
#  (0.0, 'FTO_LDA'),
#  (0.0, 'FRMD7_variance'),
#  (0.0, 'FRMD7_PCA'),
#  (0.0, 'FIGN_variance'),
#  (0.0, 'FIGN_mean'),
#  (0.0, 'FIGN_PCA'),
#  (0.0, 'FIGN_LDA'),
#  (0.0, 'FBXO43_variance'),
#  (0.0, 'FBXO43_mean'),
#  (0.0, 'FBXO43_PCA'),
#  (0.0, 'FBXO43_LDA'),
#  (0.0, 'FAM71E2_variance'),
#  (0.0, 'FAM3A_variance'),
#  (0.0, 'FAM3A_mean'),
#  (0.0, 'FAM3A_PCA'),
#  (0.0, 'FAM3A_LDA'),
#  (0.0, 'FAM216A_variance'),
#  (0.0, 'FAM216A_mean'),
#  (0.0, 'FAM216A_PCA'),
#  (0.0, 'FAM216A_LDA'),
#  (0.0, 'FAM156B_mean'),
#  (0.0, 'FAM156B_PCA'),
#  (0.0, 'FAM156B_LDA'),
#  (0.0, 'FAM120C_variance'),
#  (0.0, 'EIF2S3_mean'),
#  (0.0, 'EIF2S3_PCA'),
#  (0.0, 'EIF2S3_LDA'),
#  (0.0, 'EDC3_variance'),
#  (0.0, 'EDC3_mean'),
#  (0.0, 'EDC3_PCA'),
#  (0.0, 'EDC3_LDA'),
#  (0.0, 'ECI1_variance'),
#  (0.0, 'DUSP9_variance'),
#  (0.0, 'DUSP9_mean'),
#  (0.0, 'DUSP9_PCA'),
#  (0.0, 'DUSP9_LDA'),
#  (0.0, 'DOCK11_variance'),
#  (0.0, 'DOCK11_mean'),
#  (0.0, 'DOCK11_PCA'),
#  (0.0, 'DOCK11_LDA'),
#  (0.0, 'DKC1_variance'),
#  (0.0, 'DKC1_PCA'),
#  (0.0, 'DKC1_LDA'),
#  (0.0, 'DDX10_variance'),
#  (0.0, 'DDX10_mean'),
#  (0.0, 'DDX10_PCA'),
#  (0.0, 'DDX10_LDA'),
#  (0.0, 'DCAF16_variance'),
#  (0.0, 'DCAF16_mean'),
#  (0.0, 'DCAF16_PCA'),
#  (0.0, 'DCAF16_LDA'),
#  (0.0, 'CYP3A43_variance'),
#  (0.0, 'CYP3A43_mean'),
#  (0.0, 'CYP3A43_PCA'),
#  (0.0, 'CYP3A43_LDA'),
#  (0.0, 'CWC25_variance'),
#  (0.0, 'CWC25_mean'),
#  (0.0, 'CWC25_PCA'),
#  (0.0, 'CWC25_LDA'),
#  (0.0, 'CSAG1_variance'),
#  (0.0, 'CSAG1_mean'),
#  (0.0, 'CSAG1_PCA'),
#  (0.0, 'CSAG1_LDA'),
#  (0.0, 'COX17_variance'),
#  (0.0, 'COX17_mean'),
#  (0.0, 'COX17_PCA'),
#  (0.0, 'COX17_LDA'),
#  (0.0, 'COPE_variance'),
#  (0.0, 'COPE_mean'),
#  (0.0, 'COPE_PCA'),
#  (0.0, 'COPE_LDA'),
#  (0.0, 'COA4_variance'),
#  (0.0, 'COA4_mean'),
#  (0.0, 'COA4_PCA'),
#  (0.0, 'COA4_LDA'),
#  (0.0, 'CNR1_variance'),
#  (0.0, 'CNR1_mean'),
#  (0.0, 'CNR1_PCA'),
#  (0.0, 'CNR1_LDA'),
#  (0.0, 'CLSPN_variance'),
#  (0.0, 'CLSPN_mean'),
#  (0.0, 'CLSPN_PCA'),
#  (0.0, 'CLSPN_LDA'),
#  (0.0, 'CLDN12_variance'),
#  (0.0, 'CLDN12_mean'),
#  (0.0, 'CLDN12_PCA'),
#  (0.0, 'CLDN12_LDA'),
#  (0.0, 'CHM_variance'),
#  (0.0, 'CHM_mean'),
#  (0.0, 'CHM_PCA'),
#  (0.0, 'CHM_LDA'),
#  (0.0, 'CHIC1_variance'),
#  (0.0, 'CHIC1_mean'),
#  (0.0, 'CHIC1_PCA'),
#  (0.0, 'CHIC1_LDA'),
#  (0.0, 'CHADL_variance'),
#  (0.0, 'CHADL_mean'),
#  (0.0, 'CHADL_PCA'),
#  (0.0, 'CHADL_LDA'),
#  (0.0, 'CDKAL1_mean'),
#  (0.0, 'CDKAL1_PCA'),
#  (0.0, 'CDKAL1_LDA'),
#  (0.0, 'CD27_variance'),
#  (0.0, 'CD27_mean'),
#  (0.0, 'CD27_PCA'),
#  (0.0, 'CD247_variance'),
#  (0.0, 'CD247_mean'),
#  (0.0, 'CD247_PCA'),
#  (0.0, 'CD247_LDA'),
#  (0.0, 'CCR7_variance'),
#  (0.0, 'CCR7_mean'),
#  (0.0, 'CCR7_PCA'),
#  (0.0, 'CCR7_LDA'),
#  (0.0, 'C2orf71_variance'),
#  (0.0, 'C2orf71_mean'),
#  (0.0, 'C2orf71_PCA'),
#  (0.0, 'C2orf71_LDA'),
#  (0.0, 'C12orf56_variance'),
#  (0.0, 'C12orf56_mean'),
#  (0.0, 'C12orf56_PCA'),
#  (0.0, 'C12orf56_LDA'),
#  (0.0, 'BTK_variance'),
#  (0.0, 'BTK_mean'),
#  (0.0, 'BTK_PCA'),
#  (0.0, 'BTK_LDA'),
#  (0.0, 'ATRX_variance'),
#  (0.0, 'ATRX_mean'),
#  (0.0, 'ATRX_PCA'),
#  (0.0, 'ATRX_LDA'),
#  (0.0, 'ATP11C_variance'),
#  (0.0, 'ATP11C_PCA'),
#  (0.0, 'AR_variance'),
#  (0.0, 'AR_mean'),
#  (0.0, 'AR_PCA'),
#  (0.0, 'AR_LDA'),
#  (0.0, 'ARSH_variance'),
#  (0.0, 'ARSH_mean'),
#  (0.0, 'ARSH_PCA'),
#  (0.0, 'ARSH_LDA'),
#  (0.0, 'ARSE_LDA'),
#  (0.0, 'ARHGAP1_variance'),
#  (0.0, 'ARHGAP1_mean'),
#  (0.0, 'ARHGAP1_PCA'),
#  (0.0, 'ARHGAP1_LDA'),
#  (0.0, 'ADCY5_variance'),
#  (0.0, 'ADCY5_mean'),
#  (0.0, 'ADCY5_PCA'),
#  (0.0, 'ADCY5_LDA'),
#  (0.0, 'ADAMTS9_variance'),
#  (0.0, 'ADAMTS9_mean'),
#  (0.0, 'ADAMTS9_PCA'),
#  (0.0, 'ADAMTS9_LDA')]

# %%
'''
CLASSIFIER 1
ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='entropy',
           max_depth=None, max_features=None, max_leaf_nodes=20,
           min_samples_leaf=5, min_samples_split=5,
           min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=-1,
           oob_score=False, random_state=None, verbose=0, warm_start=False)
           
average f1-score: 0.79
'''


def extra_trees(dataset):
    
    f1_scores = []
    top_variants = np.array([])
    dataset_list = np.array(list(dataset))
    for run in range(0, 100):
        # Dividing train and test
        pre_X = dataset.drop('labels', axis = 1)
        X_train, X_test, y_train, y_test = train_test_split(pre_X, dataset['labels'], test_size = 0.3)

        print('Fitting model number: '  + str(run))

        # Random Forest Model
        rf_model = ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
           max_depth=None, max_features=None, max_leaf_nodes=20,
           min_impurity_split=1e-07, min_samples_leaf=1,
           min_samples_split=4, min_weight_fraction_leaf=0.0,
           n_estimators=50, n_jobs=-1, oob_score=False, random_state=None,
           verbose=0, warm_start=False)

        rf_model.fit(X_train, y_train)

        # To save model
        #joblib.dump(rf_model, '../../data/rf_model.pkl') 

        print('Predicting...')

        # Predicting
        # y_predicted = rf_model.predict(X_test)
        y_predicted = cross_val_predict(rf_model, X_test, y_test, cv=5)
        # print(confusion_matrix(y_test, y_predicted))

        # Saving f1 score and all indexes
        importances = rf_model.feature_importances_
        importances_indexes = np.argsort(importances)[::-1]
        importances_indexes = importances_indexes[0:100]

        print('F1-score: ' + str(f1_score(y_test, y_predicted)))
        f1_scores.append(f1_score(y_test, y_predicted))
        top_variants = np.concatenate((top_variants, dataset_list[importances_indexes]))


    # Results and important features
    f1s = mean(f1_scores)
    frequencies = Counter(top_variants)

    print('Final f1 score: ' + str(f1s))
    
    return((f1s, f1_scores, frequencies))

# %%
(f1s, f1_scores, frequencies) = extra_trees(dataset)
# Out:
# Fitting model number: 0
# Predicting...
# F1-score: 0.75
# Fitting model number: 1
# Predicting...
# F1-score: 0.604651162791
# Fitting model number: 2
# Predicting...
# F1-score: 0.736842105263
# Fitting model number: 3
# Predicting...
# F1-score: 0.809523809524
# Fitting model number: 4
# Predicting...
# F1-score: 0.666666666667
# Fitting model number: 5
# Predicting...
# F1-score: 0.872727272727
# Fitting model number: 6
# Predicting...
# F1-score: 0.837209302326
# Fitting model number: 7
# Predicting...
# F1-score: 0.684210526316
# Fitting model number: 8
# Predicting...
# F1-score: 0.867924528302
# Fitting model number: 9
# Predicting...
# F1-score: 0.864864864865
# Fitting model number: 10
# Predicting...
# F1-score: 0.808510638298
# Fitting model number: 11
# Predicting...
# F1-score: 0.652173913043
# Fitting model number: 12
# Predicting...
# F1-score: 0.8
# Fitting model number: 13
# Predicting...
# F1-score: 0.833333333333
# Fitting model number: 14
# Predicting...
# F1-score: 0.705882352941
# Fitting model number: 15
# Predicting...
# F1-score: 0.897959183673
# Fitting model number: 16
# Predicting...
# F1-score: 0.837209302326
# Fitting model number: 17
# Predicting...
# F1-score: 0.739130434783
# Fitting model number: 18
# Predicting...
# F1-score: 0.9
# Fitting model number: 19
# Predicting...
# F1-score: 0.909090909091
# Fitting model number: 20
# Predicting...
# F1-score: 0.875
# Fitting model number: 21
# Predicting...
# F1-score: 0.736842105263
# Fitting model number: 22
# Predicting...
# F1-score: 0.829268292683
# Fitting model number: 23
# Predicting...
# F1-score: 0.765957446809
# Fitting model number: 24
# Predicting...
# F1-score: 0.833333333333
# Fitting model number: 25
# Predicting...
# F1-score: 0.830188679245
# Fitting model number: 26
# Predicting...
# F1-score: 0.878048780488
# Fitting model number: 27
# Predicting...
# F1-score: 0.526315789474
# Fitting model number: 28
# Predicting...
# F1-score: 0.714285714286
# Fitting model number: 29
# Predicting...
# F1-score: 0.780487804878
# Fitting model number: 30
# Predicting...
# F1-score: 0.844444444444
# Fitting model number: 31
# Predicting...
# F1-score: 0.564102564103
# Fitting model number: 32
# Predicting...
# F1-score: 0.772727272727
# Fitting model number: 33
# Predicting...
# F1-score: 0.913043478261
# Fitting model number: 34
# Predicting...
# F1-score: 0.952380952381
# Fitting model number: 35
# Predicting...
# F1-score: 0.791666666667
# Fitting model number: 36
# Predicting...
# F1-score: 0.761904761905
# Fitting model number: 37
# Predicting...
# F1-score: 0.888888888889
# Fitting model number: 38
# Predicting...
# F1-score: 0.838709677419
# Fitting model number: 39
# Predicting...
# F1-score: 0.875
# Fitting model number: 40
# Predicting...
# F1-score: 0.844444444444
# Fitting model number: 41
# Predicting...
# F1-score: 0.628571428571
# Fitting model number: 42
# Predicting...
# F1-score: 0.625
# Fitting model number: 43
# Predicting...
# F1-score: 0.905660377358
# Fitting model number: 44
# Predicting...
# F1-score: 0.884615384615
# Fitting model number: 45
# Predicting...
# F1-score: 0.648648648649
# Fitting model number: 46
# Predicting...
# F1-score: 0.6
# Fitting model number: 47
# Predicting...
# F1-score: 0.823529411765
# Fitting model number: 48
# Predicting...
# F1-score: 0.564102564103
# Fitting model number: 49
# Predicting...
# F1-score: 0.96
# Fitting model number: 50
# Predicting...
# F1-score: 0.727272727273
# Fitting model number: 51
# Predicting...
# F1-score: 0.862745098039
# Fitting model number: 52
# Predicting...
# F1-score: 0.844444444444
# Fitting model number: 53
# Predicting...
# F1-score: 0.78431372549
# Fitting model number: 54
# Predicting...
# F1-score: 0.611111111111
# Fitting model number: 55
# Predicting...
# F1-score: 0.787878787879
# Fitting model number: 56
# Predicting...
# F1-score: 0.878048780488
# Fitting model number: 57
# Predicting...
# F1-score: 0.666666666667
# Fitting model number: 58
# Predicting...
# F1-score: 0.862745098039
# Fitting model number: 59
# Predicting...
# F1-score: 0.772727272727
# Fitting model number: 60
# Predicting...
# F1-score: 0.8
# Fitting model number: 61
# Predicting...
# F1-score: 0.846153846154
# Fitting model number: 62
# Predicting...
# F1-score: 0.888888888889
# Fitting model number: 63
# Predicting...
# F1-score: 0.872727272727
# Fitting model number: 64
# Predicting...
# F1-score: 0.851063829787
# Fitting model number: 65
# Predicting...
# F1-score: 0.754716981132
# Fitting model number: 66
# Predicting...
# F1-score: 0.961538461538
# Fitting model number: 67
# Predicting...
# F1-score: 0.666666666667
# Fitting model number: 68
# Predicting...
# F1-score: 0.787878787879
# Fitting model number: 69
# Predicting...
# F1-score: 0.810810810811
# Fitting model number: 70
# Predicting...
# F1-score: 0.787878787879
# Fitting model number: 71
# Predicting...
# F1-score: 0.615384615385
# Fitting model number: 72
# Predicting...
# F1-score: 0.892857142857
# Fitting model number: 73
# Predicting...
# F1-score: 0.892857142857
# Fitting model number: 74
# Predicting...
# F1-score: 0.740740740741
# Fitting model number: 75
# Predicting...
# F1-score: 0.918918918919
# Fitting model number: 76
# Predicting...
# F1-score: 0.647058823529
# Fitting model number: 77
# Predicting...
# F1-score: 0.961538461538
# Fitting model number: 78
# Predicting...
# F1-score: 0.918918918919
# Fitting model number: 79
# Predicting...
# F1-score: 0.871794871795
# Fitting model number: 80
# Predicting...
# F1-score: 0.790697674419
# Fitting model number: 81
# Predicting...
# F1-score: 0.8125
# Fitting model number: 82
# Predicting...
# F1-score: 0.711111111111
# Fitting model number: 83
# Predicting...
# F1-score: 0.75
# Fitting model number: 84
# Predicting...
# F1-score: 0.723404255319
# Fitting model number: 85
# Predicting...
# F1-score: 0.950819672131
# Fitting model number: 86
# Predicting...
# F1-score: 0.883720930233
# Fitting model number: 87
# Predicting...
# F1-score: 0.775510204082
# Fitting model number: 88
# Predicting...
# F1-score: 0.723404255319
# Fitting model number: 89
# Predicting...
# F1-score: 0.833333333333
# Fitting model number: 90
# Predicting...
# F1-score: 0.857142857143
# Fitting model number: 91
# Predicting...
# F1-score: 0.893617021277
# Fitting model number: 92
# Predicting...
# F1-score: 0.666666666667
# Fitting model number: 93
# Predicting...
# F1-score: 0.765957446809
# Fitting model number: 94
# Predicting...
# F1-score: 0.785714285714
# Fitting model number: 95
# Predicting...
# F1-score: 0.857142857143
# Fitting model number: 96
# Predicting...
# F1-score: 0.789473684211
# Fitting model number: 97
# Predicting...
# F1-score: 0.941176470588
# Fitting model number: 98
# Predicting...
# F1-score: 0.916666666667
# Fitting model number: 99
# Predicting...
# F1-score: 0.826086956522
# Final f1 score: 0.7977557324987419

# %% [markdown]
# ## 2.1 Selecting top features for classifier

# %%
frequencies_plot_info = pd.DataFrame(columns = ['variant', 'frequency'])

count = 0
for key in frequencies.keys():
    frequencies_plot_info.loc[count] = [key, frequencies[key]]
    count += 1

frequencies_plot_info.head()
# Out:
#         variant frequency
# 0   FAM71E2_LDA       100
# 1  FAM71E2_mean       100
# 2   FAM71E2_PCA       100
# 3     GPC4_mean        93
# 4   FAM120C_PCA        96

# %%
frequencies_plot_info['frequency'].astype(int, inplace = True)
frequencies_plot_info.sort_values(by = 'frequency', ascending = False, inplace = True)

plt.figure()
sns.set_style("whitegrid")
plot = sns.swarmplot(x = "variant", y = "frequency", data = frequencies_plot_info, color = "lightskyblue")
plot.set_xticklabels(plot.get_xticklabels(), rotation=90)
#plot.get_xaxis().set_visible(False)
plt.xlabel('Features')
plt.tight_layout()
plt.show()

# %%
top_features = frequencies_plot_info.iloc[0:50, 0]
top_features = list(top_features)
top_features.append('labels')
top_features

# New dataset
top50_dataset = dataset[list(top_features)]
top50_dataset.head()
# Out:
#    FAM71E2_LDA  FAM71E2_PCA  FAM71E2_mean  EVPLL_PCA  EVPLL_LDA   GCK_LDA  \
# 0    -0.978452    -0.871782           0.0  -0.407446   0.859112 -0.608028
# 1    -0.978452    -0.871782           0.0  -0.407446   0.859112 -0.119657
# 2     1.855746     1.954985           2.0  -0.407446   0.859112  0.007076
# 3     2.673006     0.590042           1.0  -0.407446   0.859112  1.562383
# 4     0.438647     0.541601           1.0  -0.407446   0.859112  1.140437
#
#    TAB3_LDA  GPC4_LDA  SLC38A5_LDA  MAGEB3_variance   ...    PLCD1_LDA  \
# 0  0.778193  0.778193     0.724782             0.64   ...     -0.35971
# 1  0.778193  0.778193     0.724782             0.64   ...     -0.35971
# 2  0.778193  0.778193     0.724782             0.64   ...     -0.35971
# 3  0.778193  0.778193     0.724782             0.96   ...     -0.35971
# 4  0.778193  0.778193     0.724782             0.64   ...     -0.35971
#
#    PLCD1_mean  PRR3_mean  PRR3_PCA  GCKR_mean  IGF2BP2_LDA  PLCD1_PCA  \
# 0         0.0        1.0  0.426966       0.00    -0.181177   -0.11236
# 1         0.0        2.0 -0.573034       0.25    -0.181177   -0.11236
# 2         0.0        2.0 -0.573034       0.50    -0.181177   -0.11236
# 3         0.0        1.0  0.426966       0.25    -0.181177   -0.11236
# 4         0.0        2.0 -0.573034       0.25    -0.181177   -0.11236
#
#    SERTM1_mean  ADAMTS9_LDA  labels
# 0          0.0    -0.234393       1
# 1          1.0     1.243810       1
# 2          0.0     3.194910       1
# 3          0.5     0.291459       1
# 4          0.5    -0.492642       1
#
# [5 rows x 51 columns]

# %% [markdown]
# ## 2.2 Classify with top 50 features

# %%
pre_X = top50_dataset.drop('labels', axis = 1)
X_train, X_test, y_train, y_test = train_test_split(pre_X, top50_dataset['labels'], test_size = 0.3)

param_grid = [
    {'n_estimators': [25, 50, 75, 100], 'max_features':[None], 'criterion': ['gini'],
     'min_samples_leaf':[1,2,3,5,10], 'min_samples_split':[2,4,5,8,10],
     'max_leaf_nodes': [2, 20, 50, 75, 100], 'n_jobs':[-1], 'bootstrap': [False]},
    {'n_estimators': [25, 50, 75, 100], 'max_features':[None], 'criterion': ['entropy'], 
     'min_samples_leaf':[1,2,3,5,10], 'min_samples_split':[2,4,5,8,10],
     'max_leaf_nodes': [2, 20, 50, 75, 100], 'n_jobs':[-1], 'bootstrap': [False]},
]

extra_class_full = ExtraTreesClassifier()
grid_search_full = GridSearchCV(extra_class_full, param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search_full.fit(X_train, y_train)

grid_search_full.best_estimator_
# Out:
# ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#            max_depth=None, max_features=None, max_leaf_nodes=20,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=4, min_weight_fraction_leaf=0.0,
#            n_estimators=50, n_jobs=-1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False)

# %%
'''
CLASSIFIER 1
ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='entropy',
           max_depth=None, max_features=None, max_leaf_nodes=20,
           min_samples_leaf=5, min_samples_split=5,
           min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=-1,
           oob_score=False, random_state=None, verbose=0, warm_start=False)
           
average f1-score: 0.84

CLASSIFIER 2
ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
           max_depth=None, max_features=None, max_leaf_nodes=20,
           min_impurity_split=1e-07, min_samples_leaf=1,
           min_samples_split=4, min_weight_fraction_leaf=0.0,
           n_estimators=50, n_jobs=-1, oob_score=False, random_state=None,
           verbose=0, warm_start=False)
           
average f1-score: 0.87

'''

(f1s, f1_scores, frequencies) = extra_trees(top50_dataset)
# Out:
# Fitting model number: 0
# Predicting...
# F1-score: 0.9
# Fitting model number: 1
# Predicting...
# F1-score: 0.976744186047
# Fitting model number: 2
# Predicting...
# F1-score: 0.8
# Fitting model number: 3
# Predicting...
# F1-score: 0.875
# Fitting model number: 4
# Predicting...
# F1-score: 0.916666666667
# Fitting model number: 5
# Predicting...
# F1-score: 0.901960784314
# Fitting model number: 6
# Predicting...
# F1-score: 0.842105263158
# Fitting model number: 7
# Predicting...
# F1-score: 0.765957446809
# Fitting model number: 8
# Predicting...
# F1-score: 0.905660377358
# Fitting model number: 9
# Predicting...
# F1-score: 0.857142857143
# Fitting model number: 10
# Predicting...
# F1-score: 0.857142857143
# Fitting model number: 11
# Predicting...
# F1-score: 0.904761904762
# Fitting model number: 12
# Predicting...
# F1-score: 0.96
# Fitting model number: 13
# Predicting...
# F1-score: 0.909090909091
# Fitting model number: 14
# Predicting...
# F1-score: 0.85
# Fitting model number: 15
# Predicting...
# F1-score: 0.894736842105
# Fitting model number: 16
# Predicting...
# F1-score: 0.901960784314
# Fitting model number: 17
# Predicting...
# F1-score: 0.933333333333
# Fitting model number: 18
# Predicting...
# F1-score: 0.826086956522
# Fitting model number: 19
# Predicting...
# F1-score: 0.916666666667
# Fitting model number: 20
# Predicting...
# F1-score: 0.918918918919
# Fitting model number: 21
# Predicting...
# F1-score: 0.894736842105
# Fitting model number: 22
# Predicting...
# F1-score: 0.918918918919
# Fitting model number: 23
# Predicting...
# F1-score: 0.857142857143
# Fitting model number: 24
# Predicting...
# F1-score: 0.926829268293
# Fitting model number: 25
# Predicting...
# F1-score: 0.857142857143
# Fitting model number: 26
# Predicting...
# F1-score: 0.871794871795
# Fitting model number: 27
# Predicting...
# F1-score: 0.88
# Fitting model number: 28
# Predicting...
# F1-score: 0.913043478261
# Fitting model number: 29
# Predicting...
# F1-score: 0.888888888889
# Fitting model number: 30
# Predicting...
# F1-score: 0.894736842105
# Fitting model number: 31
# Predicting...
# F1-score: 0.888888888889
# Fitting model number: 32
# Predicting...
# F1-score: 0.875
# Fitting model number: 33
# Predicting...
# F1-score: 0.833333333333
# Fitting model number: 34
# Predicting...
# F1-score: 0.909090909091
# Fitting model number: 35
# Predicting...
# F1-score: 0.818181818182
# Fitting model number: 36
# Predicting...
# F1-score: 0.941176470588
# Fitting model number: 37
# Predicting...
# F1-score: 0.830188679245
# Fitting model number: 38
# Predicting...
# F1-score: 0.888888888889
# Fitting model number: 39
# Predicting...
# F1-score: 0.88
# Fitting model number: 40
# Predicting...
# F1-score: 0.9
# Fitting model number: 41
# Predicting...
# F1-score: 0.909090909091
# Fitting model number: 42
# Predicting...
# F1-score: 0.904761904762
# Fitting model number: 43
# Predicting...
# F1-score: 0.904761904762
# Fitting model number: 44
# Predicting...
# F1-score: 0.787878787879
# Fitting model number: 45
# Predicting...
# F1-score: 0.913043478261
# Fitting model number: 46
# Predicting...
# F1-score: 0.85
# Fitting model number: 47
# Predicting...
# F1-score: 0.897959183673
# Fitting model number: 48
# Predicting...
# F1-score: 0.787878787879
# Fitting model number: 49
# Predicting...
# F1-score: 0.909090909091
# Fitting model number: 50
# Predicting...
# F1-score: 0.761904761905
# Fitting model number: 51
# Predicting...
# F1-score: 0.736842105263
# Fitting model number: 52
# Predicting...
# F1-score: 0.837209302326
# Fitting model number: 53
# Predicting...
# F1-score: 0.966666666667
# Fitting model number: 54
# Predicting...
# F1-score: 0.864864864865
# Fitting model number: 55
# Predicting...
# F1-score: 0.88
# Fitting model number: 56
# Predicting...
# F1-score: 0.857142857143
# Fitting model number: 57
# Predicting...
# F1-score: 0.980392156863
# Fitting model number: 58
# Predicting...
# F1-score: 0.9
# Fitting model number: 59
# Predicting...
# F1-score: 0.978723404255
# Fitting model number: 60
# Predicting...
# F1-score: 0.923076923077
# Fitting model number: 61
# Predicting...
# F1-score: 0.857142857143
# Fitting model number: 62
# Predicting...
# F1-score: 0.769230769231
# Fitting model number: 63
# Predicting...
# F1-score: 0.857142857143
# Fitting model number: 64
# Predicting...
# F1-score: 0.871794871795
# Fitting model number: 65
# Predicting...
# F1-score: 0.857142857143
# Fitting model number: 66
# Predicting...
# F1-score: 0.833333333333
# Fitting model number: 67
# Predicting...
# F1-score: 0.938775510204
# Fitting model number: 68
# Predicting...
# F1-score: 0.727272727273
# Fitting model number: 69
# Predicting...
# F1-score: 0.709677419355
# Fitting model number: 70
# Predicting...
# F1-score: 0.769230769231
# Fitting model number: 71
# Predicting...
# F1-score: 0.863636363636
# Fitting model number: 72
# Predicting...
# F1-score: 0.827586206897
# Fitting model number: 73
# Predicting...
# F1-score: 0.909090909091
# Fitting model number: 74
# Predicting...
# F1-score: 0.904761904762
# Fitting model number: 75
# Predicting...
# F1-score: 0.863636363636
# Fitting model number: 76
# Predicting...
# F1-score: 0.918918918919
# Fitting model number: 77
# Predicting...
# F1-score: 0.904761904762
# Fitting model number: 78
# Predicting...
# F1-score: 0.871794871795
# Fitting model number: 79
# Predicting...
# F1-score: 0.777777777778
# Fitting model number: 80
# Predicting...
# F1-score: 0.914285714286
# Fitting model number: 81
# Predicting...
# F1-score: 0.878048780488
# Fitting model number: 82
# Predicting...
# F1-score: 0.780487804878
# Fitting model number: 83
# Predicting...
# F1-score: 0.810810810811
# Fitting model number: 84
# Predicting...
# F1-score: 0.965517241379
# Fitting model number: 85
# Predicting...
# F1-score: 0.864864864865
# Fitting model number: 86
# Predicting...
# F1-score: 0.909090909091
# Fitting model number: 87
# Predicting...
# F1-score: 0.857142857143
# Fitting model number: 88
# Predicting...
# F1-score: 0.888888888889
# Fitting model number: 89
# Predicting...
# F1-score: 0.857142857143
# Fitting model number: 90
# Predicting...
# F1-score: 0.84
# Fitting model number: 91
# Predicting...
# F1-score: 0.918918918919
# Fitting model number: 92
# Predicting...
# F1-score: 0.85
# Fitting model number: 93
# Predicting...
# F1-score: 0.954545454545
# Fitting model number: 94
# Predicting...
# F1-score: 0.827586206897
# Fitting model number: 95
# Predicting...
# F1-score: 0.846153846154
# Fitting model number: 96
# Predicting...
# F1-score: 0.978723404255
# Fitting model number: 97
# Predicting...
# F1-score: 0.897959183673
# Fitting model number: 98
# Predicting...
# F1-score: 0.837209302326
# Fitting model number: 99
# Predicting...
# F1-score: 0.85
# Final f1 score: 0.8739329571384691

# %%
plt.figure()
sns.distplot(f1_scores)
plt.xlabel('F1-Scores')
plt.ylabel('Count')
plt.plot([0.87, 0.87], [0, 12], 'r-', lw=2)
plt.text(s = 'Mean', y = 8.5, x = 0.88, color = 'red')
plt.savefig("../../data/plots/f1s_top_50_rf/2.png") 
plt.show()

# %%
# top 10 features vs each other
test = top50_dataset[['FAM71E2_LDA', 'FAM71E2_mean', 'FAM71E2_PCA', 'EVPLL_PCA', 'EVPLL_LDA', 'TAB3_PCA', 'TAB3_mean', 'GPC4_mean', 'EVPLL_mean', 'MAGEB3_variance', 'labels']]

sns.pairplot(data = test, hue = 'labels')
plt.legend(['Controls', 'Cases'], loc = 0)
plt.savefig("../../data/plots/top_features_all_vs_all/1.png")
# Out:
# <img src="data:image/png;base64,..." width="2753">

# %% [markdown]
# # 3. Testing an SVM classifier

# %%
pre_X = dataset.drop('labels', axis = 1)
X_train, X_test, y_train, y_test = train_test_split(pre_X, dataset['labels'], test_size = 0.3)

param_grid = [
    {'kernel': ['linear', 'poly', 'rbf', 'sigmoid'], 'C':[0.25, 0.5, 0.75, 1, 1.5],
     'tol':[1e-3, 1e-4, 1e-5], 'gamma':[10, 25, 50, 75, 100, 150, 300, 500, 'auto'], 'degree':[1,2,3,5,10,13,17,25]}
]

svm_class_full = svm.SVC()
grid_search_full_svm = GridSearchCV(svm_class_full, param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search_full_svm.fit(X_train, y_train)

grid_search_full_svm.best_estimator_
# Out:
# SVC(C=1.5, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=1, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
'''
CLASSIFIER 1
svm.SVC(C=0.75, cache_size=200, class_weight=None, coef0=0.0,
              decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
              max_iter=-1, probability=False, random_state=None, shrinking=True,
              tol=0.001, verbose=False)
           
average f1-score: 0.83
'''


f1_scores = []
for run in range(0,100):
    X_train, X_test, y_train, y_test = train_test_split(pre_X, dataset['labels'], test_size = 0.3)

    svm_classifier = svm.SVC(C=0.75, cache_size=200, class_weight=None, coef0=0.0,
              decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
              max_iter=-1, probability=False, random_state=None, shrinking=True,
              tol=0.001, verbose=False)

    print('Fitting model number: '  + str(run))
    svm_classifier.fit(X_train, y_train)

    print('Predicting...')
    #y_predicted = svm_classifier.predict(X_test)
    y_predicted = cross_val_predict(svm_classifier, X_test, y_test, cv=5)
    print('F1 Score:' + str(f1_score(y_test, y_predicted, average = 'micro')))

    f1_scores.append(f1_score(y_test, y_predicted, average = 'micro'))

f1s = mean(f1_scores)
print('Final f1 score: ' + str(f1s))
# Out:
# Fitting model number: 0
# Predicting...
# F1 Score:0.6481481481481481
# Fitting model number: 1
# Predicting...
# F1 Score:0.9074074074074074
# Fitting model number: 2
# Predicting...
# F1 Score:1.0
# Fitting model number: 3
# Predicting...
# F1 Score:0.8333333333333334
# Fitting model number: 4
# Predicting...
# F1 Score:0.7962962962962963
# Fitting model number: 5
# Predicting...
# F1 Score:0.8518518518518519
# Fitting model number: 6
# Predicting...
# F1 Score:0.7222222222222222
# Fitting model number: 7
# Predicting...
# F1 Score:0.8703703703703703
# Fitting model number: 8
# Predicting...
# F1 Score:0.6666666666666666
# Fitting model number: 9
# Predicting...
# F1 Score:0.8148148148148148
# Fitting model number: 10
# Predicting...
# F1 Score:0.8888888888888888
# Fitting model number: 11
# Predicting...
# F1 Score:0.8518518518518519
# Fitting model number: 12
# Predicting...
# F1 Score:0.8518518518518519
# Fitting model number: 13
# Predicting...
# F1 Score:0.9444444444444444
# Fitting model number: 14
# Predicting...
# F1 Score:0.7222222222222222
# Fitting model number: 15
# Predicting...
# F1 Score:0.6666666666666666
# Fitting model number: 16
# Predicting...
# F1 Score:0.8148148148148148
# Fitting model number: 17
# Predicting...
# F1 Score:0.8518518518518519
# Fitting model number: 18
# Predicting...
# F1 Score:0.7407407407407407
# Fitting model number: 19
# Predicting...
# F1 Score:0.8703703703703703
# Fitting model number: 20
# Predicting...
# F1 Score:0.8703703703703703
# Fitting model number: 21
# Predicting...
# F1 Score:0.8888888888888888
# Fitting model number: 22
# Predicting...
# F1 Score:0.7037037037037037
# Fitting model number: 23
# Predicting...
# F1 Score:0.8703703703703703
# Fitting model number: 24
# Predicting...
# F1 Score:0.8333333333333334
# Fitting model number: 25
# Predicting...
# F1 Score:0.6666666666666666
# Fitting model number: 26
# Predicting...
# F1 Score:0.9629629629629629
# Fitting model number: 27
# Predicting...
# F1 Score:0.9814814814814815
# Fitting model number: 28
# Predicting...
# F1 Score:0.8518518518518519
# Fitting model number: 29
# Predicting...
# F1 Score:0.7037037037037037
# Fitting model number: 30
# Predicting...
# F1 Score:0.7777777777777778
# Fitting model number: 31
# Predicting...
# F1 Score:0.7962962962962963
# Fitting model number: 32
# Predicting...
# F1 Score:0.8888888888888888
# Fitting model number: 33
# Predicting...
# F1 Score:0.7777777777777778
# Fitting model number: 34
# Predicting...
# F1 Score:0.8333333333333334
# Fitting model number: 35
# Predicting...
# F1 Score:0.8333333333333334
# Fitting model number: 36
# Predicting...
# F1 Score:0.7777777777777778
# Fitting model number: 37
# Predicting...
# F1 Score:0.8703703703703703
# Fitting model number: 38
# Predicting...
# F1 Score:0.8148148148148148
# Fitting model number: 39
# Predicting...
# F1 Score:0.6851851851851852
# Fitting model number: 40
# Predicting...
# F1 Score:0.9259259259259259
# Fitting model number: 41
# Predicting...
# F1 Score:0.7222222222222222
# Fitting model number: 42
# Predicting...
# F1 Score:0.9444444444444444
# Fitting model number: 43
# Predicting...
# F1 Score:0.6851851851851852
# Fitting model number: 44
# Predicting...
# F1 Score:0.8518518518518519
# Fitting model number: 45
# Predicting...
# F1 Score:1.0
# Fitting model number: 46
# Predicting...
# F1 Score:0.7222222222222222
# Fitting model number: 47
# Predicting...
# F1 Score:0.8333333333333334
# Fitting model number: 48
# Predicting...
# F1 Score:0.6851851851851852
# Fitting model number: 49
# Predicting...
# F1 Score:0.9259259259259259
# Fitting model number: 50
# Predicting...
# F1 Score:0.8888888888888888
# Fitting model number: 51
# Predicting...
# F1 Score:0.8518518518518519
# Fitting model number: 52
# Predicting...
# F1 Score:0.8888888888888888
# Fitting model number: 53
# Predicting...
# F1 Score:0.8703703703703703
# Fitting model number: 54
# Predicting...
# F1 Score:0.9074074074074074
# Fitting model number: 55
# Predicting...
# F1 Score:0.7407407407407407
# Fitting model number: 56
# Predicting...
# F1 Score:0.8888888888888888
# Fitting model number: 57
# Predicting...
# F1 Score:0.7777777777777778
# Fitting model number: 58
# Predicting...
# F1 Score:0.6481481481481481
# Fitting model number: 59
# Predicting...
# F1 Score:0.9444444444444444
# Fitting model number: 60
# Predicting...
# F1 Score:0.8703703703703703
# Fitting model number: 61
# Predicting...
# F1 Score:0.7037037037037037
# Fitting model number: 62
# Predicting...
# F1 Score:0.9444444444444444
# Fitting model number: 63
# Predicting...
# F1 Score:0.6666666666666666
# Fitting model number: 64
# Predicting...
# F1 Score:0.8703703703703703
# Fitting model number: 65
# Predicting...
# F1 Score:0.7777777777777778
# Fitting model number: 66
# Predicting...
# F1 Score:0.8518518518518519
# Fitting model number: 67
# Predicting...
# F1 Score:0.9629629629629629
# Fitting model number: 68
# Predicting...
# F1 Score:0.8333333333333334
# Fitting model number: 69
# Predicting...
# F1 Score:0.9444444444444444
# Fitting model number: 70
# Predicting...
# F1 Score:0.9814814814814815
# Fitting model number: 71
# Predicting...
# F1 Score:0.8518518518518519
# Fitting model number: 72
# Predicting...
# F1 Score:0.9629629629629629
# Fitting model number: 73
# Predicting...
# F1 Score:0.8518518518518519
# Fitting model number: 74
# Predicting...
# F1 Score:0.9444444444444444
# Fitting model number: 75
# Predicting...
# F1 Score:0.9814814814814815
# Fitting model number: 76
# Predicting...
# F1 Score:0.9814814814814815
# Fitting model number: 77
# Predicting...
# F1 Score:0.7592592592592593
# Fitting model number: 78
# Predicting...
# F1 Score:0.7037037037037037
# Fitting model number: 79
# Predicting...
# F1 Score:0.7037037037037037
# Fitting model number: 80
# Predicting...
# F1 Score:0.7777777777777778
# Fitting model number: 81
# Predicting...
# F1 Score:0.6851851851851852
# Fitting model number: 82
# Predicting...
# F1 Score:0.7037037037037037
# Fitting model number: 83
# Predicting...
# F1 Score:0.8888888888888888
# Fitting model number: 84
# Predicting...
# F1 Score:0.9444444444444444
# Fitting model number: 85
# Predicting...
# F1 Score:0.8888888888888888
# Fitting model number: 86
# Predicting...
# F1 Score:0.8888888888888888
# Fitting model number: 87
# Predicting...
# F1 Score:0.9444444444444444
# Fitting model number: 88
# Predicting...
# F1 Score:0.7962962962962963
# Fitting model number: 89
# Predicting...
# F1 Score:0.9444444444444444
# Fitting model number: 90
# Predicting...
# F1 Score:0.7962962962962963
# Fitting model number: 91
# Predicting...
# F1 Score:0.8703703703703703
# Fitting model number: 92
# Predicting...
# F1 Score:0.9814814814814815
# Fitting model number: 93
# Predicting...
# F1 Score:0.9629629629629629
# Fitting model number: 94
# Predicting...
# F1 Score:0.6666666666666666
# Fitting model number: 95
# Predicting...
# F1 Score:0.9444444444444444
# Fitting model number: 96
# Predicting...
# F1 Score:0.6666666666666666
# Fitting model number: 97
# Predicting...
# F1 Score:0.7592592592592593
# Fitting model number: 98
# Predicting...
# F1 Score:0.7777777777777778
# Fitting model number: 99
# Predicting...
# F1 Score:0.8148148148148148
# Final f1 score: 0.8325925925925921
